# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Out:
#   Year State   County  AgDistrict                  Yield
# 1 1950 ALABAMA AUTAUGA COASTAL PLAINS & GULF COAST 15
# 2 1950 ALABAMA BALDWIN HISTORIC DISTRICT 70        20
# 3 1950 ALABAMA BARBOUR HISTORIC DISTRICT 90        15
# 4 1950 ALABAMA BIBB    HISTORIC DISTRICT 21        15
# 5 1950 ALABAMA BLOUNT  HISTORIC DISTRICT 21        13
# 6 1950 ALABAMA BULLOCK HISTORIC DISTRICT 90        16

# %%
# Out:
#   Year MeanYield
# 1 1950 18.45439
# 2 1951 17.92055
# 3 1952 18.07829
# 4 1953 15.91378
# 5 1954 16.33142
# 6 1955 17.52100

# %%
# Out:
# plot without title

# %%
# Out:
# Warning message:
# “Removed 50 rows containing missing values (geom_path).”
# plot without title
